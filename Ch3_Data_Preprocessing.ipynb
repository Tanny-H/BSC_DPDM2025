# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanny-H/BSC_DPDM2025/blob/main/Ch3_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import Data

# %% [markdown]
# # Data Cleaning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/BSC_DPDM/flooding database.csv'
flood = pd.read_csv(file_path)
display(flood.head())
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# 0    3/1/00  ...             Heavy rain           2.0    316.73
# 1   3/11/00  ...  Tropical Storm, Surge           1.0    228.50
# 2   4/25/00  ...    Snowmelt, Ice, Rain           2.0     89.10
# 3   8/10/00  ...             Heavy rain           1.0   4322.47
# 4   9/10/00  ...  Tropical Storm, Surge           1.0    740.33
#
#   gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  gfd_exp_ghsl_2015  Errors  dif 2000  \
# 0            38.0               38.0                 43       1         0
# 1          4594.0             4594.0               6855       1         0
# 2          3093.0             3093.0               4618       1         0
# 3        544758.0           544758.0             658643       1         0
# 4        785363.0           785363.0             766309       1         0
#
#    dif 2015  error 2000
# 0        -5         NaN
# 1     -2261         NaN
# 2     -1525         NaN
# 3   -113885         NaN
# 4     19054         1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Missing Data

# %% [markdown]
# ### Check Missing Data

# %%
flood.isnull().any()
# Out:
# system:index         False
# index                False
# threshold_type       False
# glide_index           True
# dfo_country          False
# dfo_other_country     True
# dfo_centroid_x       False
# dfo_centroid_y       False
# dfo_began            False
# dfo_ended             True
# dfo_validation        True
# dfo_dead             False
# dfo_displaced        False
# dfo_cause             True
# dfo_severity         False
# gfd_area             False
# gfd_exp_ghsl_ts       True
# gfd_exp_ghsl_2000     True
# gfd_exp_ghsl_2015    False
# Errors               False
# dif 2000             False
# dif 2015             False
# error 2000            True
# dtype: bool

# %%
flood.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %%
flood.shape
# Out:
# (913, 23)

# %% [markdown]
#  Drop ถ้ามี missing

# %% [markdown]
# ### Drop Record ที่มี missing ออก

# %%
flood_drop1 = flood.dropna()
flood_drop1.shape
# Out:
# (13, 23)

# %% [markdown]
# drop เฉพาะเกิด missing ตัวแปรที่เราจะใช้
#
# - dfo_country
#
# - dfo_other_country
#
# - dfo_began
#
# - dfo_ended
#
# - dfo_dead
#
# - dfo_cause
#
# - dfo_severity

# %%
flood_drop2 = flood.dropna(subset=['dfo_country','dfo_other_country','dfo_began','dfo_ended','dfo_dead','dfo_cause','dfo_severity'])
flood_drop2.shape
# Out:
# (637, 23)

# %%
flood_drop2.head()
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# 0    3/1/00  ...             Heavy rain           2.0    316.73
# 1   3/11/00  ...  Tropical Storm, Surge           1.0    228.50
# 2   4/25/00  ...    Snowmelt, Ice, Rain           2.0     89.10
# 3   8/10/00  ...             Heavy rain           1.0   4322.47
# 4   9/10/00  ...  Tropical Storm, Surge           1.0    740.33
#
#   gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  gfd_exp_ghsl_2015  Errors  dif 2000  \
# 0            38.0               38.0                 43       1         0
# 1          4594.0             4594.0               6855       1         0
# 2          3093.0             3093.0               4618       1         0
# 3        544758.0           544758.0             658643       1         0
# 4        785363.0           785363.0             766309       1         0
#
#    dif 2015  error 2000
# 0        -5         NaN
# 1     -2261         NaN
# 2     -1525         NaN
# 3   -113885         NaN
# 4     19054         1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### เติม Dummy

# %%
flood[flood.isnull()['dfo_other_country']]
# Out:
#                            system:index  index threshold_type  \
# 172  DFO_2415_From_20040110_to_20040119   2415            std
# 383  DFO_3089_From_20070530_to_20070603   3089            std
# 387  DFO_3097_From_20070611_to_20070624   3097            std
# 412  DFO_3136_From_20070721_to_20071015   3136            std
# 428  DFO_3166_From_20070726_to_20071010   3166            std
# ..                                  ...    ...            ...
# 908  DFO_4683_From_20180901_to_20181002   4683            std
# 909  DFO_4695_From_20181023_to_20181027   4695            std
# 910  DFO_4703_From_20181029_to_20181107   4703           otsu
# 911  DFO_4704_From_20181124_to_20181129   4704            std
# 912  DFO_4711_From_20181205_to_20181210   4711            std
#
#             glide_index         dfo_country dfo_other_country  dfo_centroid_x  \
# 172                   0                Iran               NaN       51.439491
# 383                   0  Dominican Republic               NaN      -71.053795
# 387  LS-2007-000080-BGD          Bangladesh               NaN       91.953546
# 412                   0          Bangladesh               NaN       91.233643
# 428  FL-2007-000132-BFA               Ghana               NaN        0.612005
# ..                  ...                 ...               ...             ...
# 908                 NaN               Ghana               NaN       -1.066060
# 909                 NaN              Mexico               NaN     -105.236000
# 910                 NaN            Paraguay               NaN      -57.085300
# 911                 NaN             Vietnam               NaN      107.137000
# 912                 NaN                 USA               NaN     -120.058000
#
#      dfo_centroid_y dfo_began dfo_ended  ...              dfo_cause  \
# 172       29.466641   1/10/04   1/19/04  ...             Heavy rain
# 383       19.547861   5/30/07    6/3/07  ...             Heavy rain
# 387       22.397464   6/11/07   6/24/07  ...             Heavy rain
# 412       23.916419   7/21/07  10/15/07  ...             Heavy rain
# 428       13.037658   7/26/07  10/10/07  ...             Heavy rain
# ..              ...       ...       ...  ...                    ...
# 908        9.537550    9/1/18   10/2/18  ...                    Dam
# 909       23.721800  10/23/18  10/27/18  ...  Tropical Storm, Surge
# 910      -25.342700  10/29/18   11/7/18  ...             Heavy rain
# 911       11.491000  11/24/18  11/29/18  ...  Tropical Storm, Surge
# 912       35.778700   12/5/18  12/10/18  ...             Heavy rain
#
#      dfo_severity  gfd_area gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  \
# 172           1.0   7017.61         23986.0            23986.0
# 383           1.0    100.92         13819.0            13819.0
# 387           1.0  20493.38       4536692.0          4536692.0
# 412           1.0  78785.53      27712991.0         27712998.0
# 428           1.5   7621.96        325408.0           325408.0
# ..            ...       ...             ...                ...
# 908           1.5   1866.91         79032.0            38895.0
# 909           1.5   2720.37         23128.0            15725.0
# 910           1.0  10019.87         29435.0            25393.0
# 911           1.0   6467.41        218916.0           173753.0
# 912           1.5   2475.92         28821.0            26654.0
#
#      gfd_exp_ghsl_2015  Errors  dif 2000  dif 2015  error 2000
# 172             116060       1         0    -92074         NaN
# 383              11672       1         0      2147         NaN
# 387            8995159       1         0  -4458467         NaN
# 412           55288622       0        -7 -27575631         NaN
# 428             624312       1         0   -298904         NaN
# ..                 ...     ...       ...       ...         ...
# 908              79032       1     40137         0         NaN
# 909              23128       1      7403         0         NaN
# 910              29435       1      4042         0         NaN
# 911             218915       0     45163         1         NaN
# 912              28821       1      2167         0         NaN
#
# [275 rows x 23 columns]

# %%
flood[~flood.isnull()['dfo_other_country']]
# Out:
#                            system:index  index threshold_type  \
# 0    DFO_1586_From_20000218_to_20000301   1586           otsu
# 1    DFO_1587_From_20000217_to_20000311   1587           otsu
# 2    DFO_1595_From_20000405_to_20000425   1595           otsu
# 3    DFO_1614_From_20000711_to_20000810   1614           otsu
# 4    DFO_1627_From_20000830_to_20000910   1627           otsu
# ..                                  ...    ...            ...
# 880  DFO_4516_From_20170908_to_20170919   4516            std
# 886  DFO_4581_From_20180310_to_20180314   4581            std
# 893  DFO_4597_From_20180325_to_20180408   4597            std
# 897  DFO_4640_From_20180625_to_20180711   4640            std
# 902  DFO_4662_From_20180726_to_20180904   4662            std
#
#             glide_index dfo_country       dfo_other_country  dfo_centroid_x  \
# 0                     0   Australia                       0      143.697800
# 1                     0  Madagascar                       0       47.295670
# 2                     0     Romania                 Hungary       22.415404
# 3                     0    Thailand                 Vietnam      105.063841
# 4                     0       China                  Russia      132.057679
# ..                  ...         ...                     ...             ...
# 880  TC-2017-000132-CUB         USA                    Cuba      -81.625156
# 886                 NaN     Croatia  Bosnia and Herzegovina       16.947210
# 893                 NaN      Greece                Bulgaria       26.671405
# 897                 NaN       India                Pakistan       75.143900
# 902                 NaN    Colombia               Venezuela      -68.294100
#
#      dfo_centroid_y dfo_began dfo_ended  ...              dfo_cause  \
# 0        -31.268059   2/18/00    3/1/00  ...             Heavy rain
# 1        -15.782624   2/17/00   3/11/00  ...  Tropical Storm, Surge
# 2         46.763746    4/5/00   4/25/00  ...    Snowmelt, Ice, Rain
# 3         11.242567   7/11/00   8/10/00  ...             Heavy rain
# 4         43.773883   8/30/00   9/10/00  ...  Tropical Storm, Surge
# ..              ...       ...       ...  ...                    ...
# 880       28.594245    9/8/17   9/19/17  ...  Tropical Storm, Surge
# 886       44.734938   3/10/18   3/14/18  ...    Snowmelt, Ice, Rain
# 893       41.531705   3/25/18    4/8/18  ...             Heavy rain
# 897       33.375200   6/25/18   7/11/18  ...             Heavy rain
# 902        2.753690   7/26/18    9/4/18  ...             Heavy rain
#
#      dfo_severity  gfd_area gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  \
# 0             2.0    316.73            38.0               38.0
# 1             1.0    228.50          4594.0             4594.0
# 2             2.0     89.10          3093.0             3093.0
# 3             1.0   4322.47        544758.0           544758.0
# 4             1.0    740.33        785363.0           785363.0
# ..            ...       ...             ...                ...
# 880           2.0   9990.79        108896.0            92345.0
# 886           1.0   1564.28         53495.0            50783.0
# 893           1.5   2818.83         57706.0            51639.0
# 897           1.0   2104.94        224236.0            60172.0
# 902           1.5   6205.09         31258.0            15208.0
#
#      gfd_exp_ghsl_2015  Errors  dif 2000  dif 2015  error 2000
# 0                   43       1         0        -5         NaN
# 1                 6855       1         0     -2261         NaN
# 2                 4618       1         0     -1525         NaN
# 3               658643       1         0   -113885         NaN
# 4               766309       1         0     19054         1.0
# ..                 ...     ...       ...       ...         ...
# 880             108883       0     16551        13         NaN
# 886              53495       1      2712         0         NaN
# 893              57706       1      6067         0         NaN
# 897             224236       1    164064         0         NaN
# 902              31258       1     16050         0         NaN
#
# [638 rows x 23 columns]

# %%
flood_filldummy = flood.fillna({'dfo_other_country':'unknow'})

# %%
flood_filldummy.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country      0
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### เติม ด้วยค่ากลาง

# %%
flood.groupby('dfo_cause').count()
# Out:
#                        system:index  index  threshold_type  glide_index  \
# dfo_cause
# Dam                              13     13              13           11
# Heavy rain                      749    749             749          554
# Snowmelt, Ice, Rain              52     52              52           45
# Tropical Storm, Surge            97     97              97           71
#
#                        dfo_country  dfo_other_country  dfo_centroid_x  \
# dfo_cause
# Dam                             13                 10              13
# Heavy rain                     749                530             749
# Snowmelt, Ice, Rain             52                 45              52
# Tropical Storm, Surge           97                 53              97
#
#                        dfo_centroid_y  dfo_began  dfo_ended  ...  \
# dfo_cause                                                    ...
# Dam                                13         13         13  ...
# Heavy rain                        749        749        748  ...
# Snowmelt, Ice, Rain                52         52         52  ...
# Tropical Storm, Surge              97         97         97  ...
#
#                        dfo_displaced  dfo_severity  gfd_area  gfd_exp_ghsl_ts  \
# dfo_cause
# Dam                               13            13        13               13
# Heavy rain                       749           749       749              748
# Snowmelt, Ice, Rain               52            52        52               52
# Tropical Storm, Surge             97            97        97               97
#
#                        gfd_exp_ghsl_2000  gfd_exp_ghsl_2015  Errors  dif 2000  \
# dfo_cause
# Dam                                   13                 13      13        13
# Heavy rain                           748                749     749       749
# Snowmelt, Ice, Rain                   52                 52      52        52
# Tropical Storm, Surge                 97                 97      97        97
#
#                        dif 2015  error 2000
# dfo_cause
# Dam                          13           0
# Heavy rain                  749          16
# Snowmelt, Ice, Rain          52           7
# Tropical Storm, Surge        97           1
#
# [4 rows x 22 columns]

# %%
flood_fillmode = flood.fillna({'dfo_cause':'Heavy rain'})

# %%
flood_fillmode.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### เติม ด้วยตัวแทนของกลุ่ม

# %%
flood.groupby(['dfo_severity','dfo_cause']).count()
# Out:
#                                     system:index  index  threshold_type  \
# dfo_severity dfo_cause
# 1.0          Dam                               9      9               9
#              Heavy rain                      464    464             464
#              Snowmelt, Ice, Rain              34     34              34
#              Tropical Storm, Surge            33     33              33
# 1.5          Dam                               3      3               3
#              Heavy rain                      163    163             163
#              Snowmelt, Ice, Rain               8      8               8
#              Tropical Storm, Surge            26     26              26
# 2.0          Dam                               1      1               1
#              Heavy rain                      122    122             122
#              Snowmelt, Ice, Rain              10     10              10
#              Tropical Storm, Surge            38     38              38
#
#                                     glide_index  dfo_country  \
# dfo_severity dfo_cause
# 1.0          Dam                              9            9
#              Heavy rain                     390          464
#              Snowmelt, Ice, Rain             29           34
#              Tropical Storm, Surge           32           33
# 1.5          Dam                              1            3
#              Heavy rain                      72          163
#              Snowmelt, Ice, Rain              7            8
#              Tropical Storm, Surge           12           26
# 2.0          Dam                              1            1
#              Heavy rain                      92          122
#              Snowmelt, Ice, Rain              9           10
#              Tropical Storm, Surge           27           38
#
#                                     dfo_other_country  dfo_centroid_x  \
# dfo_severity dfo_cause
# 1.0          Dam                                    9               9
#              Heavy rain                           369             464
#              Snowmelt, Ice, Rain                   30              34
#              Tropical Storm, Surge                 28              33
# 1.5          Dam                                    0               3
#              Heavy rain                            67             163
#              Snowmelt, Ice, Rain                    6               8
#              Tropical Storm, Surge                  7              26
# 2.0          Dam                                    1               1
#              Heavy rain                            94             122
#              Snowmelt, Ice, Rain                    9              10
#              Tropical Storm, Surge                 18              38
#
#                                     dfo_centroid_y  dfo_began  dfo_ended  ...  \
# dfo_severity dfo_cause                                                    ...
# 1.0          Dam                                 9          9          9  ...
#              Heavy rain                        464        464        463  ...
#              Snowmelt, Ice, Rain                34         34         34  ...
#              Tropical Storm, Surge              33         33         33  ...
# 1.5          Dam                                 3          3          3  ...
#              Heavy rain                        163        163        163  ...
#              Snowmelt, Ice, Rain                 8          8          8  ...
#              Tropical Storm, Surge              26         26         26  ...
# 2.0          Dam                                 1          1          1  ...
#              Heavy rain                        122        122        122  ...
#              Snowmelt, Ice, Rain                10         10         10  ...
#              Tropical Storm, Surge              38         38         38  ...
#
#                                     dfo_dead  dfo_displaced  gfd_area  \
# dfo_severity dfo_cause
# 1.0          Dam                           9              9         9
#              Heavy rain                  464            464       464
#              Snowmelt, Ice, Rain          34             34        34
#              Tropical Storm, Surge        33             33        33
# 1.5          Dam                           3              3         3
#              Heavy rain                  163            163       163
#              Snowmelt, Ice, Rain           8              8         8
#              Tropical Storm, Surge        26             26        26
# 2.0          Dam                           1              1         1
#              Heavy rain                  122            122       122
#              Snowmelt, Ice, Rain          10             10        10
#              Tropical Storm, Surge        38             38        38
#
#                                     gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  \
# dfo_severity dfo_cause
# 1.0          Dam                                  9                  9
#              Heavy rain                         463                464
#              Snowmelt, Ice, Rain                 34                 34
#              Tropical Storm, Surge               33                 33
# 1.5          Dam                                  3                  3
#              Heavy rain                         163                162
#              Snowmelt, Ice, Rain                  8                  8
#              Tropical Storm, Surge               26                 26
# 2.0          Dam                                  1                  1
#              Heavy rain                         122                122
#              Snowmelt, Ice, Rain                 10                 10
#              Tropical Storm, Surge               38                 38
#
#                                     gfd_exp_ghsl_2015  Errors  dif 2000  \
# dfo_severity dfo_cause
# 1.0          Dam                                    9       9         9
#              Heavy rain                           464     464       464
#              Snowmelt, Ice, Rain                   34      34        34
#              Tropical Storm, Surge                 33      33        33
# 1.5          Dam                                    3       3         3
#              Heavy rain                           163     163       163
#              Snowmelt, Ice, Rain                    8       8         8
#              Tropical Storm, Surge                 26      26        26
# 2.0          Dam                                    1       1         1
#              Heavy rain                           122     122       122
#              Snowmelt, Ice, Rain                   10      10        10
#              Tropical Storm, Surge                 38      38        38
#
#                                     dif 2015  error 2000
# dfo_severity dfo_cause
# 1.0          Dam                           9           0
#              Heavy rain                  464           8
#              Snowmelt, Ice, Rain          34           6
#              Tropical Storm, Surge        33           1
# 1.5          Dam                           3           0
#              Heavy rain                  163           4
#              Snowmelt, Ice, Rain           8           0
#              Tropical Storm, Surge        26           0
# 2.0          Dam                           1           0
#              Heavy rain                  122           4
#              Snowmelt, Ice, Rain          10           1
#              Tropical Storm, Surge        38           0
#
# [12 rows x 21 columns]

# %%
flood_sever1 =flood[flood['dfo_severity']==1.0]
flood_sever15 =flood[flood['dfo_severity']==1.5]
flood_sever2 =flood[flood['dfo_severity']==2.0]

# %%
flood_sever1 = flood_sever1.fillna({'dfo_cause':'Heavy rain'})
flood_sever15 = flood_sever15.fillna({'dfo_cause':'Heavy rain'})
flood_sever2 = flood_sever2.fillna({'dfo_cause':'Tropical Storm, Surge'})

# %%
flood_fillgroup = pd.concat([flood_sever1,flood_sever15,flood_sever2])

# %%
flood_fillgroup.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ## Noisy Data

# %%
flood['gfd_area']
# Out:
# 0        316.73
# 1        228.50
# 2         89.10
# 3       4322.47
# 4        740.33
#          ...
# 908     1866.91
# 909     2720.37
# 910    10019.87
# 911     6467.41
# 912     2475.92
# Name: gfd_area, Length: 913, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(flood['gfd_area'])

# %% [markdown]
# ใช้ Histrogram ดู bin ที่เหมาะสม

# %%
outputhist = plt.hist(flood['gfd_area'],30)

# %%
outputhist[1]
# Out:
# array([    0.        ,  3284.92066667,  6569.84133333,  9854.762     ,
#        13139.68266667, 16424.60333333, 19709.524     , 22994.44466667,
#        26279.36533333, 29564.286     , 32849.20666667, 36134.12733333,
#        39419.048     , 42703.96866667, 45988.88933333, 49273.81      ,
#        52558.73066667, 55843.65133333, 59128.572     , 62413.49266667,
#        65698.41333333, 68983.334     , 72268.25466667, 75553.17533333,
#        78838.096     , 82123.01666667, 85407.93733333, 88692.858     ,
#        91977.77866667, 95262.69933333, 98547.62      ])

# %%
def put_value_into_bins(value,bin_edge):
  num_bins = len(bin_edge) # Total number of edges

  # Case 1: Value is less than the first bin edge
  if value < bin_edge[0]:
      new_val = bin_edge[0] + (bin_edge[1] - bin_edge[0]) / 2
  # Case 2: Value is greater than or equal to the last bin edge
  elif value >= bin_edge[num_bins-1]:
      new_val = bin_edge[num_bins-2] + (bin_edge[num_bins-1] - bin_edge[num_bins-2]) / 2
  # Case 3: Value is within the defined bin range
  else:
      for i in range(num_bins - 1): # Iterate through bin intervals
        if value >= bin_edge[i] and value < bin_edge[i+1]:
          new_val = bin_edge[i] + (bin_edge[i+1] - bin_edge[i])/2
          break # Found the bin, no need to check further

  return new_val

# %%
put_value_into_bins(3000,outputhist[1])
# Out:
# np.float64(1642.4603333333332)

# %%
flood['gfd_area_bin']= flood['gfd_area'].apply(lambda x: put_value_into_bins(x,outputhist[1]))

# %%
plt.plot(flood['gfd_area_bin'])

# %%
plt.subplot(2,1,1)
plt.plot(flood['gfd_area'])
plt.subplot(2,1,2)
plt.plot(flood['gfd_area_bin'])

# %%
plt.subplot(2,1,1)
plt.plot(flood['gfd_area'].sort_values().reset_index(drop=True))
plt.subplot(2,1,2)
plt.plot(flood['gfd_area_bin'].sort_values().reset_index(drop=True))

# %% [markdown]
# ### Outlier Removal

# %%
plt.boxplot(flood['gfd_area'],vert=False);

# %%
outputbox = plt.boxplot(flood['gfd_area_bin'],vert=False,whis=10);

# %%
outputbox
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d3668b17e60>,
#   <matplotlib.lines.Line2D at 0x7d3668b40170>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d3668b40440>,
#   <matplotlib.lines.Line2D at 0x7d3668b406b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d3668b17bc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d3668b40950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d3668b40b00>],
#  'means': []}

# %%
outputbox['whiskers'][1].get_xdata()
# Out:
# array([ 8212.30166667, 73910.715     ])

# %%
outputbox['whiskers'][1].get_ydata()
# Out:
# array([1, 1])

# %%
outputbox['fliers'][0].get_xdata()
# Out:
# array([96905.15966667, 80480.55633333, 77195.63566667, 90335.31833333,
#        96905.15966667])

# %% [markdown]
# remove outlier

# %%
flood_nooutlier = flood[flood['gfd_area'] < outputbox['whiskers'][1].get_xdata()[1]]

# %%
outputbox2=plt.boxplot(flood_nooutlier['gfd_area'],vert=False,whis=10)

# %% [markdown]
# ตามหา outlier

# %%
flood[flood['gfd_area'].isin(outputbox['fliers'][0].get_xdata())]
# Out:
# Empty DataFrame
# Columns: [system:index, index, threshold_type, glide_index, dfo_country, dfo_other_country, dfo_centroid_x, dfo_centroid_y, dfo_began, dfo_ended, dfo_validation, dfo_dead, dfo_displaced, dfo_cause, dfo_severity, gfd_area, gfd_exp_ghsl_ts, gfd_exp_ghsl_2000, gfd_exp_ghsl_2015, Errors, dif 2000, dif 2015, error 2000, gfd_area_bin]
# Index: []
#
# [0 rows x 24 columns]

# %%
project_df = pd.read_csv('/content/drive/MyDrive/BSC_DPDM/opendata_project-2.csv')

# %%
project_df.head()
# Out:
#    row_number                project_id                     name_en  \
# 0     20809.0  5ec3409884c1860019f3298d    Baan Laksiri Surin-Korco
# 1      4268.0             project_15905              Liberty Park 2
# 2      5849.0  62b2b082cb0d2c0014be01a6  Pleno Paholyothin-Saimai 2
# 3     21762.0              project_6010              Baan Thara Rin
# 4     10751.0             project_11312             The Forest Hill
#
#                       name_th propertytype_id propertytype_name_en  \
# 0  บ้านหลักศิริ สุรินทร์-คอโค               3             Townhome
# 1          ลิเบอร์ตี้ พาร์ค 2               2                Condo
# 2    พลีโน่ พหลโยธิน-สายไหม 2               3             Townhome
# 3              บ้านธารารินทร์               1       Detached House
# 4          เดอะ ฟอเรสต์ ฮิลล์               1       Detached House
#
#   propertytype_name_th  price_min     developer_id  \
# 0             ทาวน์โฮม  1490000.0   developer_7326
# 1                คอนโด  6500000.0  developer_10510
# 2             ทาวน์โฮม  2790000.0   developer_1760
# 3                 บ้าน  3100000.0  developer_10510
# 4                 บ้าน  2450000.0   developer_7313
#
#                 developer_name_en  ... facility_park  facility_playground  \
# 0  LAK SIRI REAL ESTATE CO., LTD.  ...           NaN                  NaN
# 1                             NaN  ...           0.0                  0.0
# 2     AP (THAILAND) PUB CO., LTD.  ...           1.0                  NaN
# 3                             NaN  ...           NaN                  NaN
# 4     Cholsiri Property Co., Ltd.  ...           1.0                  NaN
#
#    facility_pool facility_security         date_created          date_finish  \
# 0            1.0               1.0  2020-05-19 09:12:40                  NaN
# 1            1.0               1.0  2019-06-28 16:06:45  1998-12-31 07:00:00
# 2            1.0               1.0  2022-06-22 13:02:42  2024-01-01 07:00:00
# 3            NaN               NaN  2017-04-19 14:41:10                  NaN
# 4            1.0               1.0  2017-10-30 14:10:50  2018-12-31 07:00:00
#
#           date_updated  source  \
# 0  2020-12-04 10:33:10  baania
# 1  2020-12-04 10:39:27  baania
# 2  2023-03-20 15:00:04  baania
# 3  2022-11-07 12:30:02  baania
# 4  2022-08-15 16:00:05  baania
#
#                                          url_project         day
# 0  https://baania.com/th/project/บ้านหลักศิริ-สุร...  2023-06-11
# 1  https://baania.com/th/project/ลิเบอร์ตี้-พาร์ค...  2023-06-11
# 2  https://baania.com/th/project/พลีโน่-พหลโยธิน-...  2023-06-11
# 3  https://baania.com/th/project/บ้านธารารินทร์-p...  2023-06-11
# 4  https://baania.com/th/project/เดอะ-ฟอเรสต์-ฮิล...  2023-06-11
#
# [5 rows x 46 columns]

# %%
for i in project_df.columns:
  print(i)
# Out:
# row_number
# project_id
# name_en
# name_th
# propertytype_id
# propertytype_name_en
# propertytype_name_th
# price_min
# developer_id
# developer_name_en
# developer_name_th
# latitude
# longitude
# neighborhood_id
# neighborhood_name_en
# neighborhood_name_th
# subdistrict_id
# subdistrict_name_en
# subdistrict_name_th
# district_id
# district_name_en
# district_name_th
# province_id
# province_name_en
# province_name_th
# zipcode
# count_elevator
# count_elevator_service
# count_floor
# count_parking
# count_tower
# count_unit
# count_unittype
# facility_clubhouse
# facility_fitness
# facility_meeting
# facility_park
# facility_playground
# facility_pool
# facility_security
# date_created
# date_finish
# date_updated
# source
# url_project
# day

# %%
unit_df = pd.read_csv('/content/drive/MyDrive/BSC_DPDM/opendata_unittype-2.csv')
unit_df
# Out:
#        row_number               unittype_id                project_id  \
# 0           37586            unittype_35602             project_15270
# 1            9427             unittype_4487              project_1476
# 2           12994            unittype_37624             project_16674
# 3           19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4           10907             unittype_8344              project_2821
# ...           ...                       ...                       ...
# 43369        9507             unittype_5086              project_1635
# 43370       23721            unittype_15644              project_6109
# 43371       31551            unittype_21385              project_8392
# 43372       29837            unittype_26243             project_10566
# 43373        9465            unittype_35686             project_15298
#
#                           name_th  propertytype_id propertytype_name_en  \
# 0                          Studio                2                Condo
# 1                         ภัทรสิน                3             Townhome
# 2                          Type B                3             Townhome
# 3                 ทาวน์โฮมสองชั้น                3             Townhome
# 4             2 Bedroom (ขายแล้ว)                2                Condo
# ...                           ...              ...                  ...
# 43369         บ้านเดี่ยวชั้นเดียว                1       Detached House
# 43370           บ้านเดี่ยวสองชั้น                1       Detached House
# 43371  อาคารพาณิชย์สี่ชั้น type B                4           Commercial
# 43372             ทาวน์โฮมสามชั้น                3             Townhome
# 43373                   2 Bedroom                2                Condo
#
#       propertytype_name_th  area_total_min_wa  area_usable_min   price_min  \
# 0                    คอนโด                NaN             30.0   3700000.0
# 1                 ทาวน์โฮม                NaN              NaN   2000000.0
# 2                 ทาวน์โฮม               24.0             96.0         NaN
# 3                 ทาวน์โฮม                NaN              NaN   1000000.0
# 4                    คอนโด                NaN             48.0   4200000.0
# ...                    ...                ...              ...         ...
# 43369                 บ้าน                NaN              NaN    880000.0
# 43370                 บ้าน               45.0            140.0   2400000.0
# 43371         อาคารพาณิชย์               34.0            192.0  13000000.0
# 43372             ทาวน์โฮม                NaN            191.0   2600000.0
# 43373                คอนโด                NaN             45.0   3490000.0
#
#        ...  count_room_kitchen  count_room_living  count_room_maid  \
# 0      ...                 NaN                NaN              NaN
# 1      ...                 NaN                NaN              NaN
# 2      ...                 NaN                NaN              NaN
# 3      ...                 1.0                NaN              NaN
# 4      ...                 1.0                1.0              NaN
# ...    ...                 ...                ...              ...
# 43369  ...                 1.0                NaN              NaN
# 43370  ...                 NaN                NaN              NaN
# 43371  ...                 NaN                NaN              NaN
# 43372  ...                 NaN                1.0              NaN
# 43373  ...                 1.0                1.0              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 0                     NaN                 NaN  2021-11-12 13:22:56
# 1                     NaN                 NaN  2021-11-12 13:20:17
# 2                     NaN                 NaN  2022-09-09 15:30:02
# 3                     NaN                 NaN  2022-03-09 16:30:04
# 4                     NaN                 NaN  2021-11-12 13:24:53
# ...                   ...                 ...                  ...
# 43369                 NaN                 NaN  2022-10-19 11:30:05
# 43370                 NaN                 NaN  2021-11-12 13:24:19
# 43371                 NaN                 NaN  2021-11-12 13:19:31
# 43372                 NaN                 NaN  2020-12-04 10:47:10
# 43373                 NaN                 NaN  2023-02-28 11:00:15
#
#               date_updated  source  \
# 0      2020-10-14 20:21:01  baania
# 1      2020-10-14 00:53:00  baania
# 2      2022-09-09 15:03:18  baania
# 3      2022-03-09 16:17:44  baania
# 4      2020-10-16 16:46:17  baania
# ...                    ...     ...
# 43369  2022-10-19 11:17:08  baania
# 43370  2020-10-14 23:03:19  baania
# 43371  2020-10-14 00:38:09  baania
# 43372  2020-10-16 16:33:56  baania
# 43373  2023-02-28 10:41:37  baania
#
#                                             url_unittype         day
# 0      https://baania.com/th/project/ไลฟ์-แอท-รัชดา-ส...  2023-06-11
# 1      https://baania.com/th/project/บ้านสวนทรัพย์ธาน...  2023-06-11
# 2      https://baania.com/th/project/สกายไลน์-อมตะ-16...  2023-06-11
# 3      https://baania.com/th/project/รุ่งเรืองทรัพย์ว...  2023-06-11
# 4      https://baania.com/th/project/เดอะ-เทมโป-แกรนด...  2023-06-11
# ...                                                  ...         ...
# 43369  https://baania.com/th/project/บ้านคุรุสภา-นครร...  2023-06-11
# 43370  https://baania.com/th/project/บ้านเต็มสิริ-1-6...  2023-06-11
# 43371  https://baania.com/th/project/พระเงิน-เพลส-839...  2023-06-11
# 43372  https://baania.com/th/project/บ้านไทยวิลล่า-ศร...  2023-06-11
# 43373  https://baania.com/th/project/แกรนด์-คอนโดมิเน...  2023-06-11
#
# [43374 rows x 28 columns]

# %%
for i in unit_df.columns:
  print(i)
# Out:
# row_number
# unittype_id
# project_id
# name_th
# propertytype_id
# propertytype_name_en
# propertytype_name_th
# area_total_min_wa
# area_usable_min
# price_min
# count_airconditioner
# count_elevator
# count_floor_internal
# count_parking
# count_room_bath
# count_room_bed
# count_room_dinning
# count_room_guest
# count_room_kitchen
# count_room_living
# count_room_maid
# count_room_storage
# count_room_utility
# date_created
# date_updated
# source
# url_unittype
# day

# %%
print('--- Information for project_df ---')
project_df.info()
# Out:
# --- Information for project_df ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23867 entries, 0 to 23866
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   row_number              23859 non-null  float64
#  1   project_id              23867 non-null  object
#  2   name_en                 23864 non-null  object
#  3   name_th                 23867 non-null  object
#  4   propertytype_id         23867 non-null  object
#  5   propertytype_name_en    23867 non-null  object
#  6   propertytype_name_th    23867 non-null  object
#  7   price_min               23806 non-null  object
#  8   developer_id            23867 non-null  object
#  9   developer_name_en       12207 non-null  object
#  10  developer_name_th       15510 non-null  object
#  11  latitude                23867 non-null  float64
#  12  longitude               23859 non-null  float64
#  13  neighborhood_id         19688 non-null  object
#  14  neighborhood_name_en    19689 non-null  object
#  15  neighborhood_name_th    19680 non-null  object
#  16  subdistrict_id          23851 non-null  float64
#  17  subdistrict_name_en     23859 non-null  object
#  18  subdistrict_name_th     23855 non-null  object
#  19  district_id             23853 non-null  float64
#  20  district_name_en        23854 non-null  object
#  21  district_name_th        23851 non-null  object
#  22  province_id             23855 non-null  float64
#  23  province_name_en        23851 non-null  object
#  24  province_name_th        23854 non-null  object
#  25  zipcode                 23838 non-null  float64
#  26  count_elevator          1892 non-null   object
#  27  count_elevator_service  601 non-null    object
#  28  count_floor             4813 non-null   object
#  29  count_parking           2011 non-null   object
#  30  count_tower             8 non-null      object
#  31  count_unit              22019 non-null  object
#  32  count_unittype          18351 non-null  float64
#  33  facility_clubhouse      6915 non-null   float64
#  34  facility_fitness        9171 non-null   float64
#  35  facility_meeting        2466 non-null   float64
#  36  facility_park           12104 non-null  float64
#  37  facility_playground     6137 non-null   float64
#  38  facility_pool           10012 non-null  float64
#  39  facility_security       16898 non-null  float64
#  40  date_created            23851 non-null  object
#  41  date_finish             10989 non-null  object
#  42  date_updated            23851 non-null  object
#  43  source                  23851 non-null  object
#  44  url_project             23851 non-null  object
#  45  day                     23851 non-null  object
# dtypes: float64(15), object(31)
# memory usage: 8.4+ MB

# %%
print('\n--- Information for unit_df ---')
unit_df.info()
# Out:
# --- Information for unit_df ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43374 entries, 0 to 43373
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_number            43374 non-null  int64
#  1   unittype_id           43374 non-null  object
#  2   project_id            43374 non-null  object
#  3   name_th               43374 non-null  object
#  4   propertytype_id       43374 non-null  int64
#  5   propertytype_name_en  43374 non-null  object
#  6   propertytype_name_th  43374 non-null  object
#  7   area_total_min_wa     3148 non-null   float64
#  8   area_usable_min       38139 non-null  float64
#  9   price_min             35123 non-null  float64
#  10  count_airconditioner  1759 non-null   float64
#  11  count_elevator        0 non-null      float64
#  12  count_floor_internal  30387 non-null  float64
#  13  count_parking         24462 non-null  float64
#  14  count_room_bath       41741 non-null  float64
#  15  count_room_bed        41543 non-null  float64
#  16  count_room_dinning    13425 non-null  float64
#  17  count_room_guest      12731 non-null  float64
#  18  count_room_kitchen    20018 non-null  float64
#  19  count_room_living     10007 non-null  float64
#  20  count_room_maid       2110 non-null   float64
#  21  count_room_storage    4012 non-null   float64
#  22  count_room_utility    887 non-null    float64
#  23  date_created          43374 non-null  object
#  24  date_updated          43374 non-null  object
#  25  source                43374 non-null  object
#  26  url_unittype          43374 non-null  object
#  27  day                   43374 non-null  object
# dtypes: float64(16), int64(2), object(10)
# memory usage: 9.3+ MB

# %%
unit_df['project_id'].map(project_df.set_index('project_id')[['name_th','developer_name_en',
                                                             'neighborhood_name_th','subdistrict_name_th',
                                                             'district_name_th','province_name_th']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-18451685.py in <cell line: 0>()
# ----> 1 unit_df['project_id'].map(project_df.set_index('project_id')[['name_th','developer_name_en',
#       2                                                              'neighborhood_name_th','subdistrict_name_th',
#       3                                                              'district_name_th','province_name_th']])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4698         dtype: object
#    4699         """
# -> 4700         new_values = self._map_values(arg, na_action=na_action)
#    4701         return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702             self, method="map"
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1722                 mapper = Series(mapper, dtype=np.float64)
#    1723             else:
# -> 1724                 mapper = Series(mapper)
#    1725
#    1726     if isinstance(mapper, ABCSeries):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     582                 data = data.copy()
#     583         else:
# --> 584             data = sanitize_array(data, index, dtype, copy)
#     585
#     586             manager = _get_option("mode.data_manager", silent=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     631         else:
#     632             data = np.array(data, copy=copy)
# --> 633         return sanitize_array(
#     634             data,
#     635             index=index,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     604             subarr = data
#     605             if data.dtype == object:
# --> 606                 subarr = maybe_infer_to_datetimelike(data)
#     607                 if (
#     608                     object_index
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/cast.py in maybe_infer_to_datetimelike(value)
#    1180     if value.ndim != 1:
#    1181         # Caller is responsible
# -> 1182         raise ValueError(value.ndim)  # pragma: no cover
#    1183
#    1184     if not len(value):
#
# ValueError: 2

# %%
unit_df['project_id'].map(project_df.set_index('project_id')['name_th'])

# %% [markdown]
# ## HW3 เติมข้อมูลคอลัมป์ที่จำเป็นที่เหลือ

# %%
unit_df['developer_name_th'] = unit_df['project_id'].map(project_df_dedup.set_index('project_id')['developer_name_th'])
unit_df['neighborhood_name_th'] = unit_df['project_id'].map(project_df_dedup.set_index('project_id')['neighborhood_name_th'])
unit_df['subdistrict_name_th'] = unit_df['project_id'].map(project_df_dedup.set_index('project_id')['subdistrict_name_th'])
unit_df['district_name_th'] = unit_df['project_id'].map(project_df_dedup.set_index('project_id')['district_name_th'])
unit_df['province_name_th'] = unit_df['project_id'].map(project_df_dedup.set_index('project_id')['province_name_th'])

# %% [markdown]
# ## Data Tranfromation

# %% [markdown]
# ## Add more data (Y-data integration)

# %%
unit_df.head()
# Out:
#    row_number               unittype_id                project_id  \
# 0       37586            unittype_35602             project_15270
# 1        9427             unittype_4487              project_1476
# 2       12994            unittype_37624             project_16674
# 3       19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4       10907             unittype_8344              project_2821
#
#                name_th  propertytype_id propertytype_name_en  \
# 0               Studio                2                Condo
# 1              ภัทรสิน                3             Townhome
# 2               Type B                3             Townhome
# 3      ทาวน์โฮมสองชั้น                3             Townhome
# 4  2 Bedroom (ขายแล้ว)                2                Condo
#
#   propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 0                คอนโด                NaN             30.0  3700000.0  ...
# 1             ทาวน์โฮม                NaN              NaN  2000000.0  ...
# 2             ทาวน์โฮม               24.0             96.0        NaN  ...
# 3             ทาวน์โฮม                NaN              NaN  1000000.0  ...
# 4                คอนโด                NaN             48.0  4200000.0  ...
#
#           date_created         date_updated  source  \
# 0  2021-11-12 13:22:56  2020-10-14 20:21:01  baania
# 1  2021-11-12 13:20:17  2020-10-14 00:53:00  baania
# 2  2022-09-09 15:30:02  2022-09-09 15:03:18  baania
# 3  2022-03-09 16:30:04  2022-03-09 16:17:44  baania
# 4  2021-11-12 13:24:53  2020-10-16 16:46:17  baania
#
#                                         url_unittype         day  \
# 0  https://baania.com/th/project/ไลฟ์-แอท-รัชดา-ส...  2023-06-11
# 1  https://baania.com/th/project/บ้านสวนทรัพย์ธาน...  2023-06-11
# 2  https://baania.com/th/project/สกายไลน์-อมตะ-16...  2023-06-11
# 3  https://baania.com/th/project/รุ่งเรืองทรัพย์ว...  2023-06-11
# 4  https://baania.com/th/project/เดอะ-เทมโป-แกรนด...  2023-06-11
#
#    developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 0                NaN                   NaN                  NaN
# 1                NaN                   NaN                  NaN
# 2                NaN                   NaN                  NaN
# 3                NaN                   NaN                  NaN
# 4                NaN                   NaN                  NaN
#
#    district_name_th  province_name_th
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# สมมติว่า database เก็บแยกข้อมูลของบ้าน

# %%
house = unit_df[unit_df['propertytype_name_th']=='บ้าน']
condo = unit_df[unit_df['propertytype_name_th']=='คอนโด']

# %%
house.head()
# Out:
#     row_number               unittype_id                project_id  \
# 6        20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 9        19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 10       12753            unittype_24670              project_9840
# 11       41256  5e9feefe38be3400128e3368  5e9fedf838be3400128e335d
# 13       29307            unittype_26473             project_10660
#
#                 name_th  propertytype_id propertytype_name_en  \
# 6                Repose                1       Detached House
# 9     บ้านเดี่ยวสองชั้น                1       Detached House
# 10                วนิดา                1       Detached House
# 11  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 13        บ้านธนวันต์ G                1       Detached House
#
#    propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 6                  บ้าน                NaN              NaN        NaN  ...
# 9                  บ้าน                NaN            100.0  6500000.0  ...
# 10                 บ้าน                NaN            203.0  4600000.0  ...
# 11                 บ้าน                NaN              NaN  2790000.0  ...
# 13                 บ้าน                NaN            215.0  5300000.0  ...
#
#            date_created         date_updated  source  \
# 6   2022-11-24 16:00:05  2022-11-24 15:30:21  baania
# 9   2022-09-12 13:00:04  2022-09-12 12:38:53  baania
# 10  2022-08-17 15:00:06  2022-08-17 14:58:24  baania
# 11  2021-11-12 13:18:38  2020-06-22 11:03:48  baania
# 13  2021-01-25 11:00:24  2021-01-25 10:46:07  baania
#
#                                          url_unittype         day  \
# 6   https://baania.com/th/project/เพอร์เฟค-มาสเตอร...  2023-06-11
# 9   https://baania.com/th/project/พนาสนธิ์-การ์เด้...  2023-06-11
# 10  https://baania.com/th/project/เพลินวิว-ทิวเขา-...  2023-06-11
# 11  https://baania.com/th/project/พราวเรสซิเดนซ์-บ...  2023-06-11
# 13  https://baania.com/th/project/บางแสน-มหานคร-10...  2023-06-11
#
#     developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 6                 NaN                   NaN                  NaN
# 9                 NaN                   NaN                  NaN
# 10                NaN                   NaN                  NaN
# 11                NaN                   NaN                  NaN
# 13                NaN                   NaN                  NaN
#
#     district_name_th  province_name_th
# 6                NaN               NaN
# 9                NaN               NaN
# 10               NaN               NaN
# 11               NaN               NaN
# 13               NaN               NaN
#
# [5 rows x 33 columns]

# %%
house.shape
# Out:
# (17777, 33)

# %%
condo.head()
# Out:
#     row_number     unittype_id     project_id              name_th  \
# 0        37586  unittype_35602  project_15270               Studio
# 4        10907   unittype_8344   project_2821  2 Bedroom (ขายแล้ว)
# 8        33884  unittype_36928  project_15818            1 Bedroom
# 14       34574  unittype_37590  project_16368            4 Bedroom
# 16       39469  unittype_40049  project_17461            2 Bedroom
#
#     propertytype_id propertytype_name_en propertytype_name_th  \
# 0                 2                Condo                คอนโด
# 4                 2                Condo                คอนโด
# 8                 2                Condo                คอนโด
# 14                2                Condo                คอนโด
# 16                2                Condo                คอนโด
#
#     area_total_min_wa  area_usable_min   price_min  ...         date_created  \
# 0                 NaN            30.00   3700000.0  ...  2021-11-12 13:22:56
# 4                 NaN            48.00   4200000.0  ...  2021-11-12 13:24:53
# 8                 NaN            49.00   3350000.0  ...  2021-11-12 13:22:58
# 14                NaN           170.00  15900000.0  ...  2021-11-12 13:23:00
# 16                NaN            48.88   4700000.0  ...  2023-05-11 16:00:05
#
#            date_updated  source  \
# 0   2020-10-14 20:21:01  baania
# 4   2020-10-16 16:46:17  baania
# 8   2020-10-14 20:24:11  baania
# 14  2020-10-14 20:27:19  baania
# 16  2023-05-11 15:30:26  baania
#
#                                          url_unittype         day  \
# 0   https://baania.com/th/project/ไลฟ์-แอท-รัชดา-ส...  2023-06-11
# 4   https://baania.com/th/project/เดอะ-เทมโป-แกรนด...  2023-06-11
# 8   https://baania.com/th/project/ทองหล่อ-ทาวเวอร์...  2023-06-11
# 14  https://baania.com/th/project/จิวเวลรี่-เทรด-เ...  2023-06-11
# 16  https://baania.com/th/project/อะไรส์-รัชดา-19-...  2023-06-11
#
#     developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 0                 NaN                   NaN                  NaN
# 4                 NaN                   NaN                  NaN
# 8                 NaN                   NaN                  NaN
# 14                NaN                   NaN                  NaN
# 16                NaN                   NaN                  NaN
#
#     district_name_th  province_name_th
# 0                NaN               NaN
# 4                NaN               NaN
# 8                NaN               NaN
# 14               NaN               NaN
# 16               NaN               NaN
#
# [5 rows x 33 columns]

# %%
condo.shape
# Out:
# (12806, 33)

# %% [markdown]
# รวมข้อมูลบ้านและคอนโด

# %% [markdown]
# ตรวจสอบ scale คร่าวๆ

# %%
house_condo = pd.concat([house,condo])
house_condo.head()
# Out:
#     row_number               unittype_id                project_id  \
# 6        20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 9        19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 10       12753            unittype_24670              project_9840
# 11       41256  5e9feefe38be3400128e3368  5e9fedf838be3400128e335d
# 13       29307            unittype_26473             project_10660
#
#                 name_th  propertytype_id propertytype_name_en  \
# 6                Repose                1       Detached House
# 9     บ้านเดี่ยวสองชั้น                1       Detached House
# 10                วนิดา                1       Detached House
# 11  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 13        บ้านธนวันต์ G                1       Detached House
#
#    propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 6                  บ้าน                NaN              NaN        NaN  ...
# 9                  บ้าน                NaN            100.0  6500000.0  ...
# 10                 บ้าน                NaN            203.0  4600000.0  ...
# 11                 บ้าน                NaN              NaN  2790000.0  ...
# 13                 บ้าน                NaN            215.0  5300000.0  ...
#
#            date_created         date_updated  source  \
# 6   2022-11-24 16:00:05  2022-11-24 15:30:21  baania
# 9   2022-09-12 13:00:04  2022-09-12 12:38:53  baania
# 10  2022-08-17 15:00:06  2022-08-17 14:58:24  baania
# 11  2021-11-12 13:18:38  2020-06-22 11:03:48  baania
# 13  2021-01-25 11:00:24  2021-01-25 10:46:07  baania
#
#                                          url_unittype         day  \
# 6   https://baania.com/th/project/เพอร์เฟค-มาสเตอร...  2023-06-11
# 9   https://baania.com/th/project/พนาสนธิ์-การ์เด้...  2023-06-11
# 10  https://baania.com/th/project/เพลินวิว-ทิวเขา-...  2023-06-11
# 11  https://baania.com/th/project/พราวเรสซิเดนซ์-บ...  2023-06-11
# 13  https://baania.com/th/project/บางแสน-มหานคร-10...  2023-06-11
#
#     developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 6                 NaN                   NaN                  NaN
# 9                 NaN                   NaN                  NaN
# 10                NaN                   NaN                  NaN
# 11                NaN                   NaN                  NaN
# 13                NaN                   NaN                  NaN
#
#     district_name_th  province_name_th
# 6                NaN               NaN
# 9                NaN               NaN
# 10               NaN               NaN
# 11               NaN               NaN
# 13               NaN               NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ในกรณีที่ ข้อมูลใน column เดียวกันใช้ หน่วยไม่เหมือนกัน ต้องมีการแปลงข้อมูลก่อน

# %% [markdown]
# ทำให้หน่วยของราคา ไม่เท่ากัน(condo หน่วยบาท vs house หน่วยล้านบาท)

# %%
house['price_min'] = house['price_min']/1000000
house
# Out:
# /tmp/ipython-input-3989735810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['price_min'] = house['price_min']/1000000
#        row_number               unittype_id                project_id  \
# 6           20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 9           19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 10          12753            unittype_24670              project_9840
# 11          41256  5e9feefe38be3400128e3368  5e9fedf838be3400128e335d
# 13          29307            unittype_26473             project_10660
# ...           ...                       ...                       ...
# 43361        2451            unittype_13544              project_5287
# 43363        1055             unittype_5786              project_1886
# 43367       20108  630dc1c8713e23001a6a6bb1  630dc0f7713e23001a6a6ba9
# 43369        9507             unittype_5086              project_1635
# 43370       23721            unittype_15644              project_6109
#
#                         name_th  propertytype_id propertytype_name_en  \
# 6                        Repose                1       Detached House
# 9             บ้านเดี่ยวสองชั้น                1       Detached House
# 10                        วนิดา                1       Detached House
# 11          บ้านเดี่ยวชั้นเดียว                1       Detached House
# 13                บ้านธนวันต์ G                1       Detached House
# ...                         ...              ...                  ...
# 43361  บ้านเดี่ยวสองชั้น Type B                1       Detached House
# 43363           กฤษณา PLUS-EV89                1       Detached House
# 43367                    Type A                1       Detached House
# 43369       บ้านเดี่ยวชั้นเดียว                1       Detached House
# 43370         บ้านเดี่ยวสองชั้น                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 6                     บ้าน                NaN              NaN        NaN
# 9                     บ้าน                NaN            100.0     6.5000
# 10                    บ้าน                NaN            203.0     4.6000
# 11                    บ้าน                NaN              NaN     2.7900
# 13                    บ้าน                NaN            215.0     5.3000
# ...                    ...                ...              ...        ...
# 43361                 บ้าน                NaN            160.0     3.2000
# 43363                 บ้าน                2.0            170.0     3.8614
# 43367                 บ้าน                NaN            186.0     5.3900
# 43369                 บ้าน                NaN              NaN     0.8800
# 43370                 บ้าน               45.0            140.0     2.4000
#
#        ...         date_created         date_updated  source  \
# 6      ...  2022-11-24 16:00:05  2022-11-24 15:30:21  baania
# 9      ...  2022-09-12 13:00:04  2022-09-12 12:38:53  baania
# 10     ...  2022-08-17 15:00:06  2022-08-17 14:58:24  baania
# 11     ...  2021-11-12 13:18:38  2020-06-22 11:03:48  baania
# 13     ...  2021-01-25 11:00:24  2021-01-25 10:46:07  baania
# ...    ...                  ...                  ...     ...
# 43361  ...  2020-12-04 10:38:02  2020-10-14 00:47:42  baania
# 43363  ...  2021-11-12 13:24:08  2020-10-14 22:26:15  baania
# 43367  ...  2023-03-28 15:00:05  2023-03-28 14:50:41  baania
# 43369  ...  2022-10-19 11:30:05  2022-10-19 11:17:08  baania
# 43370  ...  2021-11-12 13:24:19  2020-10-14 23:03:19  baania
#
#                                             url_unittype         day  \
# 6      https://baania.com/th/project/เพอร์เฟค-มาสเตอร...  2023-06-11
# 9      https://baania.com/th/project/พนาสนธิ์-การ์เด้...  2023-06-11
# 10     https://baania.com/th/project/เพลินวิว-ทิวเขา-...  2023-06-11
# 11     https://baania.com/th/project/พราวเรสซิเดนซ์-บ...  2023-06-11
# 13     https://baania.com/th/project/บางแสน-มหานคร-10...  2023-06-11
# ...                                                  ...         ...
# 43361  https://baania.com/th/project/บ้านณัฐชากรีนวิล...  2023-06-11
# 43363  https://baania.com/th/project/กลันตา-พลัส-อีโค...  2023-06-11
# 43367  https://baania.com/th/project/ชวนชม-5-630dc0f7...  2023-06-11
# 43369  https://baania.com/th/project/บ้านคุรุสภา-นครร...  2023-06-11
# 43370  https://baania.com/th/project/บ้านเต็มสิริ-1-6...  2023-06-11
#
#        developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 6                    NaN                   NaN                  NaN
# 9                    NaN                   NaN                  NaN
# 10                   NaN                   NaN                  NaN
# 11                   NaN                   NaN                  NaN
# 13                   NaN                   NaN                  NaN
# ...                  ...                   ...                  ...
# 43361                NaN                   NaN                  NaN
# 43363                NaN                   NaN                  NaN
# 43367                NaN                   NaN                  NaN
# 43369                NaN                   NaN                  NaN
# 43370                NaN                   NaN                  NaN
#
#        district_name_th  province_name_th
# 6                   NaN               NaN
# 9                   NaN               NaN
# 10                  NaN               NaN
# 11                  NaN               NaN
# 13                  NaN               NaN
# ...                 ...               ...
# 43361               NaN               NaN
# 43363               NaN               NaN
# 43367               NaN               NaN
# 43369               NaN               NaN
# 43370               NaN               NaN
#
# [17777 rows x 33 columns]

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(range(len(house['price_min'])),house['price_min'],c='r')
plt.scatter(range(len(condo['price_min'])),condo['price_min'],c='g')

# %% [markdown]
# แปลงค่า หน่วย ของ คอนโดหลักล้านแล้วรวม Data

# %%
condo['price_min'] = condo['price_min']/1000000
condo_house = pd.concat([house,condo])
plt.scatter(range(len(condo_house['price_min'])),condo_house['price_min'],c='g')
# Out:
# /tmp/ipython-input-3265899580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo['price_min'] = condo['price_min']/1000000

# %%
condo_house[condo_house['price_min']>300] ['url_unittype'].values
# Out:
# array(['https://baania.com/th/project/อสงไขย-63f6e3b09b028e00130ae6e5/บ้านเดี่ยวสามชั้น-63f6e58e9b028e00130ae6f6',
#        'https://baania.com/th/project/บันยัน-ทรี-เรสซิเดนซ์-ริเวอร์ไซด์-กรุงเทพ-15531/penthouse-unittype_36249',
#        'https://baania.com/th/project/โฟร์ซีซั่นส์-ไพรเวท-เรสซิเด้นซ์-2540/penthouse-unittype_7639',
#        'https://baania.com/th/project/เดอะ-สุโขทัย-เรสซิเด้นซ์-16305/penthouse-unittype_37324'],
#       dtype=object)

# %%
condo_house[condo_house['price_min']>300]
# Out:
#        row_number               unittype_id                project_id  \
# 30469       21591  63f6e58e9b028e00130ae6f6  63f6e3b09b028e00130ae6e5
# 11071       11195            unittype_36249             project_15531
# 19928        4397             unittype_7639              project_2540
# 20668       34097            unittype_37324             project_16305
#
#                  name_th  propertytype_id propertytype_name_en  \
# 30469  บ้านเดี่ยวสามชั้น                1       Detached House
# 11071          Penthouse                2                Condo
# 19928          Penthouse                2                Condo
# 20668          Penthouse                2                Condo
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 30469                 บ้าน                NaN          2918.00      385.0
# 11071                คอนโด                NaN           844.56      400.0
# 19928                คอนโด                NaN          1050.00      315.0
# 20668                คอนโด                NaN          1182.00      580.0
#
#        ...         date_created         date_updated  source  \
# 30469  ...  2023-02-23 11:30:03  2023-02-23 11:05:42  baania
# 11071  ...  2023-05-27 07:30:02  2023-05-27 07:19:29  baania
# 19928  ...  2021-11-12 13:20:45  2020-10-14 00:56:43  baania
# 20668  ...  2021-11-12 13:20:31  2020-10-14 00:55:50  baania
#
#                                             url_unittype         day  \
# 30469  https://baania.com/th/project/อสงไขย-63f6e3b09...  2023-06-11
# 11071  https://baania.com/th/project/บันยัน-ทรี-เรสซิ...  2023-06-11
# 19928  https://baania.com/th/project/โฟร์ซีซั่นส์-ไพร...  2023-06-11
# 20668  https://baania.com/th/project/เดอะ-สุโขทัย-เรส...  2023-06-11
#
#        developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 30469                NaN                   NaN                  NaN
# 11071                NaN                   NaN                  NaN
# 19928                NaN                   NaN                  NaN
# 20668                NaN                   NaN                  NaN
#
#        district_name_th  province_name_th
# 30469               NaN               NaN
# 11071               NaN               NaN
# 19928               NaN               NaN
# 20668               NaN               NaN
#
# [4 rows x 33 columns]

# %% [markdown]
# ## Column Alignment

# %% [markdown]
# สลับ column ของ data condo

# %%
condo.columns
# Out:
# Index(['row_number', 'unittype_id', 'project_id', 'name_th', 'propertytype_id',
#        'propertytype_name_en', 'propertytype_name_th', 'area_total_min_wa',
#        'area_usable_min', 'price_min', 'count_airconditioner',
#        'count_elevator', 'count_floor_internal', 'count_parking',
#        'count_room_bath', 'count_room_bed', 'count_room_dinning',
#        'count_room_guest', 'count_room_kitchen', 'count_room_living',
#        'count_room_maid', 'count_room_storage', 'count_room_utility',
#        'date_created', 'date_updated', 'source', 'url_unittype', 'day',
#        'developer_name_th', 'neighborhood_name_th', 'subdistrict_name_th',
#        'district_name_th', 'province_name_th'],
#       dtype='object')

# %%
columns_titles = ['row_number', 'unittype_id', 'project_id', 'name_th', 'propertytype_id',
       'propertytype_name_en', 'propertytype_name_th', 'area_total_min_wa',
       'area_usable_min', 'price_min', 'count_airconditioner',
       'count_elevator', 'count_floor_internal', 'count_parking',
       'count_room_bath', 'count_room_bed', 'count_room_dinning',
       'count_room_guest', 'count_room_kitchen', 'count_room_living',
       'count_room_maid', 'count_room_storage', 'count_room_utility',
       'date_created', 'date_updated', 'source', 'url_unittype', 'day',
       'developer_name_th', 'neighborhood_name_th', 'subdistrict_name_th',
       'district_name_th', 'province_name_th'
       ]
condo_swap = condo.reindex(columns=columns_titles)
condo_swap
# Out:
#        row_number               unittype_id                project_id  \
# 0           37586            unittype_35602             project_15270
# 4           10907             unittype_8344              project_2821
# 8           33884            unittype_36928             project_15818
# 14          34574            unittype_37590             project_16368
# 16          39469            unittype_40049             project_17461
# ...           ...                       ...                       ...
# 43355       17263  60488b2e582962001402e663  60488aeca8b9ee0013d7ebac
# 43357       32766            unittype_32126             project_13619
# 43364       12599            unittype_24778              project_9877
# 43366       11147            unittype_35831             project_15356
# 43373        9465            unittype_35686             project_15298
#
#                    name_th  propertytype_id propertytype_name_en  \
# 0                   Studio                2                Condo
# 4      2 Bedroom (ขายแล้ว)                2                Condo
# 8                1 Bedroom                2                Condo
# 14               4 Bedroom                2                Condo
# 16               2 Bedroom                2                Condo
# ...                    ...              ...                  ...
# 43355            1 Bedroom                2                Condo
# 43357           1 Bedroom                 2                Condo
# 43364            2 Bedroom                2                Condo
# 43366               Studio                2                Condo
# 43373            2 Bedroom                2                Condo
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 0                    คอนโด                NaN            30.00       3.70
# 4                    คอนโด                NaN            48.00       4.20
# 8                    คอนโด                NaN            49.00       3.35
# 14                   คอนโด                NaN           170.00      15.90
# 16                   คอนโด                NaN            48.88       4.70
# ...                    ...                ...              ...        ...
# 43355                คอนโด                NaN              NaN        NaN
# 43357                คอนโด                NaN            31.00       6.50
# 43364                คอนโด                NaN            49.00       3.50
# 43366                คอนโด                NaN            27.00       4.99
# 43373                คอนโด                NaN            45.00       3.49
#
#        ...         date_created         date_updated  source  \
# 0      ...  2021-11-12 13:22:56  2020-10-14 20:21:01  baania
# 4      ...  2021-11-12 13:24:53  2020-10-16 16:46:17  baania
# 8      ...  2021-11-12 13:22:58  2020-10-14 20:24:11  baania
# 14     ...  2021-11-12 13:23:00  2020-10-14 20:27:19  baania
# 16     ...  2023-05-11 16:00:05  2023-05-11 15:30:26  baania
# ...    ...                  ...                  ...     ...
# 43355  ...  2021-03-10 16:30:04  2021-03-10 16:07:33  baania
# 43357  ...  2022-05-17 15:30:05  2022-05-17 15:17:54  baania
# 43364  ...  2022-08-18 15:00:06  2022-08-18 14:44:59  baania
# 43366  ...  2022-09-22 15:00:06  2022-09-22 14:56:47  baania
# 43373  ...  2023-02-28 11:00:15  2023-02-28 10:41:37  baania
#
#                                             url_unittype         day  \
# 0      https://baania.com/th/project/ไลฟ์-แอท-รัชดา-ส...  2023-06-11
# 4      https://baania.com/th/project/เดอะ-เทมโป-แกรนด...  2023-06-11
# 8      https://baania.com/th/project/ทองหล่อ-ทาวเวอร์...  2023-06-11
# 14     https://baania.com/th/project/จิวเวลรี่-เทรด-เ...  2023-06-11
# 16     https://baania.com/th/project/อะไรส์-รัชดา-19-...  2023-06-11
# ...                                                  ...         ...
# 43355  https://baania.com/th/project/เดอะ-ไพรเวซี่-พา...  2023-06-11
# 43357  https://baania.com/th/project/วาลเด้น-อโศก-136...  2023-06-11
# 43364  https://baania.com/th/project/ซีซี-คอนโดมิเนีย...  2023-06-11
# 43366  https://baania.com/th/project/ไอดีโอ-โมบิ-รางน...  2023-06-11
# 43373  https://baania.com/th/project/แกรนด์-คอนโดมิเน...  2023-06-11
#
#        developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 0                    NaN                   NaN                  NaN
# 4                    NaN                   NaN                  NaN
# 8                    NaN                   NaN                  NaN
# 14                   NaN                   NaN                  NaN
# 16                   NaN                   NaN                  NaN
# ...                  ...                   ...                  ...
# 43355                NaN                   NaN                  NaN
# 43357                NaN                   NaN                  NaN
# 43364                NaN                   NaN                  NaN
# 43366                NaN                   NaN                  NaN
# 43373                NaN                   NaN                  NaN
#
#        district_name_th  province_name_th
# 0                   NaN               NaN
# 4                   NaN               NaN
# 8                   NaN               NaN
# 14                  NaN               NaN
# 16                  NaN               NaN
# ...                 ...               ...
# 43355               NaN               NaN
# 43357               NaN               NaN
# 43364               NaN               NaN
# 43366               NaN               NaN
# 43373               NaN               NaN
#
# [12806 rows x 33 columns]

# %%
condoswap_house = pd.concat([house,condo_swap])
condoswap_house
# Out:
#        row_number               unittype_id                project_id  \
# 6           20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 9           19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 10          12753            unittype_24670              project_9840
# 11          41256  5e9feefe38be3400128e3368  5e9fedf838be3400128e335d
# 13          29307            unittype_26473             project_10660
# ...           ...                       ...                       ...
# 43355       17263  60488b2e582962001402e663  60488aeca8b9ee0013d7ebac
# 43357       32766            unittype_32126             project_13619
# 43364       12599            unittype_24778              project_9877
# 43366       11147            unittype_35831             project_15356
# 43373        9465            unittype_35686             project_15298
#
#                    name_th  propertytype_id propertytype_name_en  \
# 6                   Repose                1       Detached House
# 9        บ้านเดี่ยวสองชั้น                1       Detached House
# 10                   วนิดา                1       Detached House
# 11     บ้านเดี่ยวชั้นเดียว                1       Detached House
# 13           บ้านธนวันต์ G                1       Detached House
# ...                    ...              ...                  ...
# 43355            1 Bedroom                2                Condo
# 43357           1 Bedroom                 2                Condo
# 43364            2 Bedroom                2                Condo
# 43366               Studio                2                Condo
# 43373            2 Bedroom                2                Condo
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 6                     บ้าน                NaN              NaN        NaN
# 9                     บ้าน                NaN            100.0       6.50
# 10                    บ้าน                NaN            203.0       4.60
# 11                    บ้าน                NaN              NaN       2.79
# 13                    บ้าน                NaN            215.0       5.30
# ...                    ...                ...              ...        ...
# 43355                คอนโด                NaN              NaN        NaN
# 43357                คอนโด                NaN             31.0       6.50
# 43364                คอนโด                NaN             49.0       3.50
# 43366                คอนโด                NaN             27.0       4.99
# 43373                คอนโด                NaN             45.0       3.49
#
#        ...         date_created         date_updated  source  \
# 6      ...  2022-11-24 16:00:05  2022-11-24 15:30:21  baania
# 9      ...  2022-09-12 13:00:04  2022-09-12 12:38:53  baania
# 10     ...  2022-08-17 15:00:06  2022-08-17 14:58:24  baania
# 11     ...  2021-11-12 13:18:38  2020-06-22 11:03:48  baania
# 13     ...  2021-01-25 11:00:24  2021-01-25 10:46:07  baania
# ...    ...                  ...                  ...     ...
# 43355  ...  2021-03-10 16:30:04  2021-03-10 16:07:33  baania
# 43357  ...  2022-05-17 15:30:05  2022-05-17 15:17:54  baania
# 43364  ...  2022-08-18 15:00:06  2022-08-18 14:44:59  baania
# 43366  ...  2022-09-22 15:00:06  2022-09-22 14:56:47  baania
# 43373  ...  2023-02-28 11:00:15  2023-02-28 10:41:37  baania
#
#                                             url_unittype         day  \
# 6      https://baania.com/th/project/เพอร์เฟค-มาสเตอร...  2023-06-11
# 9      https://baania.com/th/project/พนาสนธิ์-การ์เด้...  2023-06-11
# 10     https://baania.com/th/project/เพลินวิว-ทิวเขา-...  2023-06-11
# 11     https://baania.com/th/project/พราวเรสซิเดนซ์-บ...  2023-06-11
# 13     https://baania.com/th/project/บางแสน-มหานคร-10...  2023-06-11
# ...                                                  ...         ...
# 43355  https://baania.com/th/project/เดอะ-ไพรเวซี่-พา...  2023-06-11
# 43357  https://baania.com/th/project/วาลเด้น-อโศก-136...  2023-06-11
# 43364  https://baania.com/th/project/ซีซี-คอนโดมิเนีย...  2023-06-11
# 43366  https://baania.com/th/project/ไอดีโอ-โมบิ-รางน...  2023-06-11
# 43373  https://baania.com/th/project/แกรนด์-คอนโดมิเน...  2023-06-11
#
#        developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 6                    NaN                   NaN                  NaN
# 9                    NaN                   NaN                  NaN
# 10                   NaN                   NaN                  NaN
# 11                   NaN                   NaN                  NaN
# 13                   NaN                   NaN                  NaN
# ...                  ...                   ...                  ...
# 43355                NaN                   NaN                  NaN
# 43357                NaN                   NaN                  NaN
# 43364                NaN                   NaN                  NaN
# 43366                NaN                   NaN                  NaN
# 43373                NaN                   NaN                  NaN
#
#        district_name_th  province_name_th
# 6                   NaN               NaN
# 9                   NaN               NaN
# 10                  NaN               NaN
# 11                  NaN               NaN
# 13                  NaN               NaN
# ...                 ...               ...
# 43355               NaN               NaN
# 43357               NaN               NaN
# 43364               NaN               NaN
# 43366               NaN               NaN
# 43373               NaN               NaN
#
# [30583 rows x 33 columns]

# %%
condoswap_house.head()
# Out:
#     row_number               unittype_id                project_id  \
# 6        20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 9        19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 10       12753            unittype_24670              project_9840
# 11       41256  5e9feefe38be3400128e3368  5e9fedf838be3400128e335d
# 13       29307            unittype_26473             project_10660
#
#                 name_th  propertytype_id propertytype_name_en  \
# 6                Repose                1       Detached House
# 9     บ้านเดี่ยวสองชั้น                1       Detached House
# 10                วนิดา                1       Detached House
# 11  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 13        บ้านธนวันต์ G                1       Detached House
#
#    propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 6                  บ้าน                NaN              NaN        NaN  ...
# 9                  บ้าน                NaN            100.0       6.50  ...
# 10                 บ้าน                NaN            203.0       4.60  ...
# 11                 บ้าน                NaN              NaN       2.79  ...
# 13                 บ้าน                NaN            215.0       5.30  ...
#
#            date_created         date_updated  source  \
# 6   2022-11-24 16:00:05  2022-11-24 15:30:21  baania
# 9   2022-09-12 13:00:04  2022-09-12 12:38:53  baania
# 10  2022-08-17 15:00:06  2022-08-17 14:58:24  baania
# 11  2021-11-12 13:18:38  2020-06-22 11:03:48  baania
# 13  2021-01-25 11:00:24  2021-01-25 10:46:07  baania
#
#                                          url_unittype         day  \
# 6   https://baania.com/th/project/เพอร์เฟค-มาสเตอร...  2023-06-11
# 9   https://baania.com/th/project/พนาสนธิ์-การ์เด้...  2023-06-11
# 10  https://baania.com/th/project/เพลินวิว-ทิวเขา-...  2023-06-11
# 11  https://baania.com/th/project/พราวเรสซิเดนซ์-บ...  2023-06-11
# 13  https://baania.com/th/project/บางแสน-มหานคร-10...  2023-06-11
#
#     developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 6                 NaN                   NaN                  NaN
# 9                 NaN                   NaN                  NaN
# 10                NaN                   NaN                  NaN
# 11                NaN                   NaN                  NaN
# 13                NaN                   NaN                  NaN
#
#     district_name_th  province_name_th
# 6                NaN               NaN
# 9                NaN               NaN
# 10               NaN               NaN
# 11               NaN               NaN
# 13               NaN               NaN
#
# [5 rows x 33 columns]

# %%
condo_swap['price_min_bath']= condo_swap['price_min']*1000000

# %%
condo_swap.shape
# Out:
# (12806, 34)

# %%
house.shape
# Out:
# (17777, 33)

# %% [markdown]
# ## Add Data Source Column

# %% [markdown]
# เตรียมปัญหาโดย การลบ column property type ออก

# %%
house.head()
# Out:
#     row_number               unittype_id                project_id  \
# 6        20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 9        19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 10       12753            unittype_24670              project_9840
# 11       41256  5e9feefe38be3400128e3368  5e9fedf838be3400128e335d
# 13       29307            unittype_26473             project_10660
#
#                 name_th  propertytype_id propertytype_name_en  \
# 6                Repose                1       Detached House
# 9     บ้านเดี่ยวสองชั้น                1       Detached House
# 10                วนิดา                1       Detached House
# 11  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 13        บ้านธนวันต์ G                1       Detached House
#
#    propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 6                  บ้าน                NaN              NaN        NaN  ...
# 9                  บ้าน                NaN            100.0       6.50  ...
# 10                 บ้าน                NaN            203.0       4.60  ...
# 11                 บ้าน                NaN              NaN       2.79  ...
# 13                 บ้าน                NaN            215.0       5.30  ...
#
#            date_created         date_updated  source  \
# 6   2022-11-24 16:00:05  2022-11-24 15:30:21  baania
# 9   2022-09-12 13:00:04  2022-09-12 12:38:53  baania
# 10  2022-08-17 15:00:06  2022-08-17 14:58:24  baania
# 11  2021-11-12 13:18:38  2020-06-22 11:03:48  baania
# 13  2021-01-25 11:00:24  2021-01-25 10:46:07  baania
#
#                                          url_unittype         day  \
# 6   https://baania.com/th/project/เพอร์เฟค-มาสเตอร...  2023-06-11
# 9   https://baania.com/th/project/พนาสนธิ์-การ์เด้...  2023-06-11
# 10  https://baania.com/th/project/เพลินวิว-ทิวเขา-...  2023-06-11
# 11  https://baania.com/th/project/พราวเรสซิเดนซ์-บ...  2023-06-11
# 13  https://baania.com/th/project/บางแสน-มหานคร-10...  2023-06-11
#
#     developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 6                 NaN                   NaN                  NaN
# 9                 NaN                   NaN                  NaN
# 10                NaN                   NaN                  NaN
# 11                NaN                   NaN                  NaN
# 13                NaN                   NaN                  NaN
#
#     district_name_th  province_name_th
# 6                NaN               NaN
# 9                NaN               NaN
# 10               NaN               NaN
# 11               NaN               NaN
# 13               NaN               NaN
#
# [5 rows x 33 columns]

# %%
house=house.drop(columns=['propertytype_id','propertytype_name_en','propertytype_name_th'])
condo=condo.drop(columns=['propertytype_id','propertytype_name_en','propertytype_name_th'])

# %%
condo.head()
# Out:
#     row_number     unittype_id     project_id              name_th  \
# 0        37586  unittype_35602  project_15270               Studio
# 4        10907   unittype_8344   project_2821  2 Bedroom (ขายแล้ว)
# 8        33884  unittype_36928  project_15818            1 Bedroom
# 14       34574  unittype_37590  project_16368            4 Bedroom
# 16       39469  unittype_40049  project_17461            2 Bedroom
#
#     area_total_min_wa  area_usable_min  price_min  count_airconditioner  \
# 0                 NaN            30.00       3.70                   NaN
# 4                 NaN            48.00       4.20                   NaN
# 8                 NaN            49.00       3.35                   NaN
# 14                NaN           170.00      15.90                   NaN
# 16                NaN            48.88       4.70                   NaN
#
#     count_elevator  count_floor_internal  ...         date_created  \
# 0              NaN                   NaN  ...  2021-11-12 13:22:56
# 4              NaN                   NaN  ...  2021-11-12 13:24:53
# 8              NaN                   NaN  ...  2021-11-12 13:22:58
# 14             NaN                   NaN  ...  2021-11-12 13:23:00
# 16             NaN                   NaN  ...  2023-05-11 16:00:05
#
#            date_updated  source  \
# 0   2020-10-14 20:21:01  baania
# 4   2020-10-16 16:46:17  baania
# 8   2020-10-14 20:24:11  baania
# 14  2020-10-14 20:27:19  baania
# 16  2023-05-11 15:30:26  baania
#
#                                          url_unittype         day  \
# 0   https://baania.com/th/project/ไลฟ์-แอท-รัชดา-ส...  2023-06-11
# 4   https://baania.com/th/project/เดอะ-เทมโป-แกรนด...  2023-06-11
# 8   https://baania.com/th/project/ทองหล่อ-ทาวเวอร์...  2023-06-11
# 14  https://baania.com/th/project/จิวเวลรี่-เทรด-เ...  2023-06-11
# 16  https://baania.com/th/project/อะไรส์-รัชดา-19-...  2023-06-11
#
#     developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 0                 NaN                   NaN                  NaN
# 4                 NaN                   NaN                  NaN
# 8                 NaN                   NaN                  NaN
# 14                NaN                   NaN                  NaN
# 16                NaN                   NaN                  NaN
#
#     district_name_th  province_name_th
# 0                NaN               NaN
# 4                NaN               NaN
# 8                NaN               NaN
# 14               NaN               NaN
# 16               NaN               NaN
#
# [5 rows x 30 columns]

# %%
house['data_source'] = 'house'
condo['data_source'] = 'condo'

# Re-concatenate the DataFrames after adding the new column
condoswap_house = pd.concat([house, condo])

# Display the head of the combined DataFrame to show the new column
condoswap_house.head()
# Out:
#     row_number               unittype_id                project_id  \
# 6        20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 9        19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 10       12753            unittype_24670              project_9840
# 11       41256  5e9feefe38be3400128e3368  5e9fedf838be3400128e335d
# 13       29307            unittype_26473             project_10660
#
#                 name_th  area_total_min_wa  area_usable_min  price_min  \
# 6                Repose                NaN              NaN        NaN
# 9     บ้านเดี่ยวสองชั้น                NaN            100.0       6.50
# 10                วนิดา                NaN            203.0       4.60
# 11  บ้านเดี่ยวชั้นเดียว                NaN              NaN       2.79
# 13        บ้านธนวันต์ G                NaN            215.0       5.30
#
#     count_airconditioner  count_elevator  count_floor_internal  ...  \
# 6                    NaN             NaN                   2.0  ...
# 9                    NaN             NaN                   2.0  ...
# 10                   NaN             NaN                   2.0  ...
# 11                   NaN             NaN                   1.0  ...
# 13                   NaN             NaN                   2.0  ...
#
#            date_updated  source  \
# 6   2022-11-24 15:30:21  baania
# 9   2022-09-12 12:38:53  baania
# 10  2022-08-17 14:58:24  baania
# 11  2020-06-22 11:03:48  baania
# 13  2021-01-25 10:46:07  baania
#
#                                          url_unittype         day  \
# 6   https://baania.com/th/project/เพอร์เฟค-มาสเตอร...  2023-06-11
# 9   https://baania.com/th/project/พนาสนธิ์-การ์เด้...  2023-06-11
# 10  https://baania.com/th/project/เพลินวิว-ทิวเขา-...  2023-06-11
# 11  https://baania.com/th/project/พราวเรสซิเดนซ์-บ...  2023-06-11
# 13  https://baania.com/th/project/บางแสน-มหานคร-10...  2023-06-11
#
#     developer_name_th  neighborhood_name_th  subdistrict_name_th  \
# 6                 NaN                   NaN                  NaN
# 9                 NaN                   NaN                  NaN
# 10                NaN                   NaN                  NaN
# 11                NaN                   NaN                  NaN
# 13                NaN                   NaN                  NaN
#
#     district_name_th  province_name_th  data_source
# 6                NaN               NaN        house
# 9                NaN               NaN        house
# 10               NaN               NaN        house
# 11               NaN               NaN        house
# 13               NaN               NaN        house
#
# [5 rows x 31 columns]
